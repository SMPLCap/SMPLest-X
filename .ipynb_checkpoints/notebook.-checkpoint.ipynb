# %%
import numpy as np
from pathlib import Path

# %%
read = dict(np.load( Path("humandata_prep/data/annot/hd_10sample.npz")))
print(read.keys())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 read = dict(np.load( Path("humandata_prep/data/annot/hd_10sample.npz")))
#       2 print(read.keys())
#
# File c:\Users\gzaz976\AppData\Local\anaconda3\envs\fifa-skeletal\Lib\site-packages\numpy\lib\_npyio_impl.py:257, in NpzFile.__getitem__(self, key)
#     247 bytes.seek(0)
#     248 if magic == format.MAGIC_PREFIX:
#     249     # FIXME: This seems like it will copy strings around
#     250     #   more than is strictly necessary.  The zipfile
#    (...)    255     #   (or at least uncompress) the data
#     256     #   directly into the array memory.
# --> 257     return format.read_array(
#     258         bytes,
#     259         allow_pickle=self.allow_pickle,
#     260         pickle_kwargs=self.pickle_kwargs,
#     261         max_header_size=self.max_header_size
#     262     )
# ...
